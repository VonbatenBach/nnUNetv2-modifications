# %%
import multiprocessing
import os
from copy import deepcopy
from multiprocessing import Pool
from typing import Tuple, List, Union, Optional

import numpy as np
from batchgenerators.utilities.file_and_folder_operations import subfiles, join, save_json, load_json, isfile
from nnunetv2.configuration import default_num_processes
from nnunetv2.imageio.base_reader_writer import BaseReaderWriter
from nnunetv2.imageio.reader_writer_registry import determine_reader_writer_from_dataset_json, determine_reader_writer_from_file_ending
from nnunetv2.imageio.simpleitk_reader_writer import SimpleITKIO
# the Evaluator class of the previous nnU-Net was great and all but man was it overengineered. Keep it simple
from nnunetv2.utilities.json_export import recursive_fix_for_json_export
from nnunetv2.utilities.plans_handling.plans_handler import PlansManager
from nnunetv2.evaluation.evaluate_predictions import compute_metrics_on_folder

# %%
folder_ref = '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr'
folder_pred = '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation'
output_file = '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/summary.json'
image_reader_writer = SimpleITKIO()
file_ending = '.nrrd'
labels = [1]
ignore_label = None
num_processes = 12
compute_metrics_on_folder(folder_ref, folder_pred, output_file, image_reader_writer, file_ending, labels, ignore_label, num_processes)
# Out:
# {'metric_per_case': [{'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0004.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0004.nrrd',
#    'metrics': {1: {'Dice': 0.8257050392972723,
#      'IoU': 0.7031496062992126,
#      'FP': 248,
#      'TP': 893,
#      'FN': 129,
#      'TN': 42990346,
#      'n_pred': 1141,
#      'n_ref': 1022}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0007.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0007.nrrd',
#    'metrics': {1: {'Dice': 0.47450381679389314,
#      'IoU': 0.311048839071257,
#      'FP': 1102,
#      'TP': 777,
#      'FN': 619,
#      'TN': 41743934,
#      'n_pred': 1879,
#      'n_ref': 1396}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0014.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0014.nrrd',
#    'metrics': {1: {'Dice': 0.5876363636363636,
#      'IoU': 0.4160659114315139,
#      'FP': 455,
#      'TP': 404,
#      'FN': 112,
#      'TN': 35322933,
#      'n_pred': 859,
#      'n_ref': 516}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0017.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0017.nrrd',
#    'metrics': {1: {'Dice': 0.6437833714721587,
#      'IoU': 0.4746906636670416,
#      'FP': 423,
#      'TP': 844,
#      'FN': 511,
#      'TN': 35322126,
#      'n_pred': 1267,
#      'n_ref': 1355}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0024.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0024.nrrd',
#    'metrics': {1: {'Dice': 0.16305632138637258,
#      'IoU': 0.08876500857632934,
#      'FP': 2117,
#      'TP': 207,
#      'FN': 8,
#      'TN': 47183588,
#      'n_pred': 2324,
#      'n_ref': 215}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0029.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0029.nrrd',
#    'metrics': {1: {'Dice': 0.5838621940163191,
#      'IoU': 0.41229193341869397,
#      'FP': 338,
#      'TP': 322,
#      'FN': 121,
#      'TN': 50330867,
#      'n_pred': 660,
#      'n_ref': 443}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0037.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0037.nrrd',
#    'metrics': {1: {'Dice': 0.49489795918367346,
#      'IoU': 0.3288135593220339,
#      'FP': 683,
#      'TP': 388,
#      'FN': 109,
#      'TN': 14744420,
#      'n_pred': 1071,
#      'n_ref': 497}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0039.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0039.nrrd',
#    'metrics': {1: {'Dice': 0.537253072017421,
#      'IoU': 0.36729051467460655,
#      'FP': 1953,
#      'TP': 1727,
#      'FN': 1022,
#      'TN': 32107938,
#      'n_pred': 3680,
#      'n_ref': 2749}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0049.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0049.nrrd',
#    'metrics': {1: {'Dice': 0.7759226713532513,
#      'IoU': 0.633883704235463,
#      'FP': 194,
#      'TP': 883,
#      'FN': 316,
#      'TN': 42990223,
#      'n_pred': 1077,
#      'n_ref': 1199}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0050.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0050.nrrd',
#    'metrics': {1: {'Dice': 0.720656756157089,
#      'IoU': 0.5633021158515436,
#      'FP': 927,
#      'TP': 1624,
#      'FN': 332,
#      'TN': 50328765,
#      'n_pred': 2551,
#      'n_ref': 1956}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0051.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0051.nrrd',
#    'metrics': {1: {'Dice': 0.1127373417721519,
#      'IoU': 0.05973590442255292,
#      'FP': 1602,
#      'TP': 285,
#      'FN': 2884,
#      'TN': 52424029,
#      'n_pred': 1887,
#      'n_ref': 3169}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0052.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0052.nrrd',
#    'metrics': {1: {'Dice': 0.8882878009196646,
#      'IoU': 0.7990267639902676,
#      'FP': 107,
#      'TP': 1642,
#      'FN': 306,
#      'TN': 25688057,
#      'n_pred': 1749,
#      'n_ref': 1948}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0059.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0059.nrrd',
#    'metrics': {1: {'Dice': 0.7613261127988377,
#      'IoU': 0.6146299850714438,
#      'FP': 497,
#      'TP': 2882,
#      'FN': 1310,
#      'TN': 47705519,
#      'n_pred': 3379,
#      'n_ref': 4192}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0062.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0062.nrrd',
#    'metrics': {1: {'Dice': 0.7565800228870361,
#      'IoU': 0.6084669997370497,
#      'FP': 1216,
#      'TP': 2314,
#      'FN': 273,
#      'TN': 42987813,
#      'n_pred': 3530,
#      'n_ref': 2587}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0067.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0067.nrrd',
#    'metrics': {1: {'Dice': 0.8048472607927291,
#      'IoU': 0.6734262779890157,
#      'FP': 174,
#      'TP': 1594,
#      'FN': 599,
#      'TN': 32110273,
#      'n_pred': 1768,
#      'n_ref': 2193}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0072.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0072.nrrd',
#    'metrics': {1: {'Dice': 0.5622233152975897,
#      'IoU': 0.3910366062264796,
#      'FP': 954,
#      'TP': 1143,
#      'FN': 826,
#      'TN': 14742677,
#      'n_pred': 2097,
#      'n_ref': 1969}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0073.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0073.nrrd',
#    'metrics': {1: {'Dice': 0.6762285445567835,
#      'IoU': 0.5108348134991119,
#      'FP': 1375,
#      'TP': 2876,
#      'FN': 1379,
#      'TN': 46131714,
#      'n_pred': 4251,
#      'n_ref': 4255}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0075.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0075.nrrd',
#    'metrics': {1: {'Dice': 0.5743721828718609,
#      'IoU': 0.4028906955736224,
#      'FP': 374,
#      'TP': 446,
#      'FN': 287,
#      'TN': 41745325,
#      'n_pred': 820,
#      'n_ref': 733}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0076.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0076.nrrd',
#    'metrics': {1: {'Dice': 0.4573852680293097,
#      'IoU': 0.2965,
#      'FP': 185,
#      'TP': 593,
#      'FN': 1222,
#      'TN': 16382000,
#      'n_pred': 778,
#      'n_ref': 1815}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0084.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0084.nrrd',
#    'metrics': {1: {'Dice': 0.6182026330852891,
#      'IoU': 0.44739022369511183,
#      'FP': 7,
#      'TP': 540,
#      'FN': 660,
#      'TN': 41745225,
#      'n_pred': 547,
#      'n_ref': 1200}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0088.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0088.nrrd',
#    'metrics': {1: {'Dice': 0.7506944444444444,
#      'IoU': 0.6008893829905503,
#      'FP': 1286,
#      'TP': 2162,
#      'FN': 150,
#      'TN': 47182322,
#      'n_pred': 3448,
#      'n_ref': 2312}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0092.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0092.nrrd',
#    'metrics': {1: {'Dice': 0.889261744966443,
#      'IoU': 0.8006042296072508,
#      'FP': 88,
#      'TP': 1060,
#      'FN': 176,
#      'TN': 16382676,
#      'n_pred': 1148,
#      'n_ref': 1236}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0093.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0093.nrrd',
#    'metrics': {1: {'Dice': 0.7094835680751174,
#      'IoU': 0.54976717112922,
#      'FP': 660,
#      'TP': 1889,
#      'FN': 887,
#      'TN': 39318164,
#      'n_pred': 2549,
#      'n_ref': 2776}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0095.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0095.nrrd',
#    'metrics': {1: {'Dice': 0.6244925575101489,
#      'IoU': 0.45400885391047713,
#      'FP': 285,
#      'TP': 923,
#      'FN': 825,
#      'TN': 35321871,
#      'n_pred': 1208,
#      'n_ref': 1748}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0102.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0102.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 1007,
#      'TP': 0,
#      'FN': 1151,
#      'TN': 39319442,
#      'n_pred': 1007,
#      'n_ref': 1151}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0109.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0109.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 2291,
#      'TP': 0,
#      'FN': 1446,
#      'TN': 42463591,
#      'n_pred': 2291,
#      'n_ref': 1446}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0110.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0110.nrrd',
#    'metrics': {1: {'Dice': 0.7240861291937907,
#      'IoU': 0.5675039246467818,
#      'FP': 412,
#      'TP': 723,
#      'FN': 139,
#      'TN': 49281798,
#      'n_pred': 1135,
#      'n_ref': 862}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0111.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0111.nrrd',
#    'metrics': {1: {'Dice': 0.7969798657718121,
#      'IoU': 0.6624825662482566,
#      'FP': 198,
#      'TP': 475,
#      'FN': 44,
#      'TN': 37748019,
#      'n_pred': 673,
#      'n_ref': 519}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0113.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0113.nrrd',
#    'metrics': {1: {'Dice': 0.8883928571428571,
#      'IoU': 0.7991967871485943,
#      'FP': 23,
#      'TP': 199,
#      'FN': 27,
#      'TN': 43515655,
#      'n_pred': 222,
#      'n_ref': 226}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0118.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0118.nrrd',
#    'metrics': {1: {'Dice': 0.8125232948192322,
#      'IoU': 0.6842435655994978,
#      'FP': 187,
#      'TP': 1090,
#      'FN': 316,
#      'TN': 46135751,
#      'n_pred': 1277,
#      'n_ref': 1406}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0120.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0120.nrrd',
#    'metrics': {1: {'Dice': 0.6600512163892446,
#      'IoU': 0.4925943621595795,
#      'FP': 594,
#      'TP': 1031,
#      'FN': 468,
#      'TN': 12040147,
#      'n_pred': 1625,
#      'n_ref': 1499}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0121.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0121.nrrd',
#    'metrics': {1: {'Dice': 0.8354430379746836,
#      'IoU': 0.717391304347826,
#      'FP': 10,
#      'TP': 198,
#      'FN': 68,
#      'TN': 32112364,
#      'n_pred': 208,
#      'n_ref': 266}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0124.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0124.nrrd',
#    'metrics': {1: {'Dice': 0.7525912573231185,
#      'IoU': 0.6033236994219653,
#      'FP': 329,
#      'TP': 835,
#      'FN': 220,
#      'TN': 35322520,
#      'n_pred': 1164,
#      'n_ref': 1055}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0126.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0126.nrrd',
#    'metrics': {1: {'Dice': 0.21487603305785125,
#      'IoU': 0.12037037037037036,
#      'FP': 27,
#      'TP': 793,
#      'FN': 5768,
#      'TN': 32106052,
#      'n_pred': 820,
#      'n_ref': 6561}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0127.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0127.nrrd',
#    'metrics': {1: {'Dice': 0.4001584786053883,
#      'IoU': 0.2501238236750867,
#      'FP': 853,
#      'TP': 505,
#      'FN': 661,
#      'TN': 32110621,
#      'n_pred': 1358,
#      'n_ref': 1166}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0129.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0129.nrrd',
#    'metrics': {1: {'Dice': 0.03704074481930123,
#      'IoU': 0.01886984904120767,
#      'FP': 2766,
#      'TP': 185,
#      'FN': 6853,
#      'TN': 49273268,
#      'n_pred': 2951,
#      'n_ref': 7038}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0133.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0133.nrrd',
#    'metrics': {1: {'Dice': 0.7834132967786155,
#      'IoU': 0.643943661971831,
#      'FP': 687,
#      'TP': 2286,
#      'FN': 577,
#      'TN': 37220898,
#      'n_pred': 2973,
#      'n_ref': 2863}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0138.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0138.nrrd',
#    'metrics': {1: {'Dice': 0.45003756574004505,
#      'IoU': 0.29035385361124577,
#      'FP': 1398,
#      'TP': 599,
#      'FN': 66,
#      'TN': 50329585,
#      'n_pred': 1997,
#      'n_ref': 665}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0142.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0142.nrrd',
#    'metrics': {1: {'Dice': 0.4481024234110654,
#      'IoU': 0.2887448438420743,
#      'FP': 1100,
#      'TP': 490,
#      'FN': 107,
#      'TN': 35322207,
#      'n_pred': 1590,
#      'n_ref': 597}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0143.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0143.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 416,
#      'TP': 0,
#      'FN': 543,
#      'TN': 25689153,
#      'n_pred': 416,
#      'n_ref': 543}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0145.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0145.nrrd',
#    'metrics': {1: {'Dice': 0.8053627005027532,
#      'IoU': 0.6741482965931864,
#      'FP': 443,
#      'TP': 1682,
#      'FN': 370,
#      'TN': 46134849,
#      'n_pred': 2125,
#      'n_ref': 2052}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0147.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0147.nrrd',
#    'metrics': {1: {'Dice': 0.7284105131414268,
#      'IoU': 0.5728346456692913,
#      'FP': 264,
#      'TP': 582,
#      'FN': 170,
#      'TN': 46136328,
#      'n_pred': 846,
#      'n_ref': 752}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0154.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0154.nrrd',
#    'metrics': {1: {'Dice': 0.7420814479638009,
#      'IoU': 0.5899280575539568,
#      'FP': 311,
#      'TP': 1066,
#      'FN': 430,
#      'TN': 52426993,
#      'n_pred': 1377,
#      'n_ref': 1496}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0164.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0164.nrrd',
#    'metrics': {1: {'Dice': 0.6574675324675324,
#      'IoU': 0.48972188633615477,
#      'FP': 720,
#      'TP': 810,
#      'FN': 124,
#      'TN': 41744778,
#      'n_pred': 1530,
#      'n_ref': 934}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0165.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0165.nrrd',
#    'metrics': {1: {'Dice': 0.7649063032367973,
#      'IoU': 0.6193103448275862,
#      'FP': 139,
#      'TP': 449,
#      'FN': 137,
#      'TN': 28900651,
#      'n_pred': 588,
#      'n_ref': 586}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0166.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0166.nrrd',
#    'metrics': {1: {'Dice': 0.49687716863289383,
#      'IoU': 0.33056325023084027,
#      'FP': 260,
#      'TP': 358,
#      'FN': 465,
#      'TN': 28900293,
#      'n_pred': 618,
#      'n_ref': 823}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0169.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0169.nrrd',
#    'metrics': {1: {'Dice': 0.22902025630425796,
#      'IoU': 0.1293183940242764,
#      'FP': 4,
#      'TP': 277,
#      'FN': 1861,
#      'TN': 35321762,
#      'n_pred': 281,
#      'n_ref': 2138}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0174.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0174.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 639,
#      'TP': 0,
#      'FN': 189,
#      'TN': 37223620,
#      'n_pred': 639,
#      'n_ref': 189}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0177.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0177.nrrd',
#    'metrics': {1: {'Dice': 0.5754081174180021,
#      'IoU': 0.4039108494533221,
#      'FP': 1002,
#      'TP': 1921,
#      'FN': 1833,
#      'TN': 38530412,
#      'n_pred': 2923,
#      'n_ref': 3754}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0181.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0181.nrrd',
#    'metrics': {1: {'Dice': 0.39892183288409705,
#      'IoU': 0.24915824915824916,
#      'FP': 428,
#      'TP': 148,
#      'FN': 18,
#      'TN': 22478254,
#      'n_pred': 576,
#      'n_ref': 166}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0184.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0184.nrrd',
#    'metrics': {1: {'Dice': 0.5992217898832685,
#      'IoU': 0.42777777777777776,
#      'FP': 88,
#      'TP': 462,
#      'FN': 530,
#      'TN': 48233416,
#      'n_pred': 550,
#      'n_ref': 992}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0187.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0187.nrrd',
#    'metrics': {1: {'Dice': 0.5198963974570285,
#      'IoU': 0.35125676105631565,
#      'FP': 289,
#      'TP': 1104,
#      'FN': 1750,
#      'TN': 46134201,
#      'n_pred': 1393,
#      'n_ref': 2854}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0190.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0190.nrrd',
#    'metrics': {1: {'Dice': 0.7070938215102975,
#      'IoU': 0.5469026548672566,
#      'FP': 328,
#      'TP': 927,
#      'FN': 440,
#      'TN': 52427105,
#      'n_pred': 1255,
#      'n_ref': 1367}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0193.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0193.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 1762,
#      'TP': 0,
#      'FN': 2378,
#      'TN': 46133204,
#      'n_pred': 1762,
#      'n_ref': 2378}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0204.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0204.nrrd',
#    'metrics': {1: {'Dice': 0.7529597474348856,
#      'IoU': 0.6037974683544304,
#      'FP': 91,
#      'TP': 477,
#      'FN': 222,
#      'TN': 41745642,
#      'n_pred': 568,
#      'n_ref': 699}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0207.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0207.nrrd',
#    'metrics': {1: {'Dice': 0.6289855072463768,
#      'IoU': 0.4587737843551797,
#      'FP': 238,
#      'TP': 217,
#      'FN': 18,
#      'TN': 50855463,
#      'n_pred': 455,
#      'n_ref': 235}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0209.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0209.nrrd',
#    'metrics': {1: {'Dice': 0.8662345315262228,
#      'IoU': 0.764033264033264,
#      'FP': 101,
#      'TP': 735,
#      'FN': 126,
#      'TN': 24083518,
#      'n_pred': 836,
#      'n_ref': 861}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0210.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0210.nrrd',
#    'metrics': {1: {'Dice': 0.23026315789473684,
#      'IoU': 0.13011152416356878,
#      'FP': 47,
#      'TP': 35,
#      'FN': 187,
#      'TN': 28901107,
#      'n_pred': 82,
#      'n_ref': 222}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0215.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0215.nrrd',
#    'metrics': {1: {'Dice': 0.7857142857142857,
#      'IoU': 0.6470588235294118,
#      'FP': 474,
#      'TP': 1012,
#      'FN': 78,
#      'TN': 32111076,
#      'n_pred': 1486,
#      'n_ref': 1090}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0220.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0220.nrrd',
#    'metrics': {1: {'Dice': 0.8069286016054077,
#      'IoU': 0.6763456090651558,
#      'FP': 260,
#      'TP': 955,
#      'FN': 197,
#      'TN': 45611644,
#      'n_pred': 1215,
#      'n_ref': 1152}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0232.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0232.nrrd',
#    'metrics': {1: {'Dice': 0.35340796372396205,
#      'IoU': 0.21462994836488813,
#      'FP': 3235,
#      'TP': 1247,
#      'FN': 1328,
#      'TN': 49801550,
#      'n_pred': 4482,
#      'n_ref': 2575}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0235.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0235.nrrd',
#    'metrics': {1: {'Dice': 0.5979954111822243,
#      'IoU': 0.42652885443583116,
#      'FP': 711,
#      'TP': 2476,
#      'FN': 2618,
#      'TN': 44034387,
#      'n_pred': 3187,
#      'n_ref': 5094}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0243.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0243.nrrd',
#    'metrics': {1: {'Dice': 0.628078561779071,
#      'IoU': 0.45780942281472503,
#      'FP': 2191,
#      'TP': 3022,
#      'FN': 1388,
#      'TN': 50325047,
#      'n_pred': 5213,
#      'n_ref': 4410}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0247.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0247.nrrd',
#    'metrics': {1: {'Dice': 0.5168717745136959,
#      'IoU': 0.3485010706638116,
#      'FP': 1032,
#      'TP': 651,
#      'FN': 185,
#      'TN': 41941172,
#      'n_pred': 1683,
#      'n_ref': 836}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0248.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0248.nrrd',
#    'metrics': {1: {'Dice': 0.6627423822714681,
#      'IoU': 0.4955981356809943,
#      'FP': 466,
#      'TP': 957,
#      'FN': 508,
#      'TN': 50329717,
#      'n_pred': 1423,
#      'n_ref': 1465}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0259.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0259.nrrd',
#    'metrics': {1: {'Dice': 0.570316301703163,
#      'IoU': 0.39891082368958475,
#      'FP': 1410,
#      'TP': 1172,
#      'FN': 356,
#      'TN': 42464390,
#      'n_pred': 2582,
#      'n_ref': 1528}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0262.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0262.nrrd',
#    'metrics': {1: {'Dice': 0.763542093054987,
#      'IoU': 0.6175237254469212,
#      'FP': 629,
#      'TP': 2798,
#      'FN': 1104,
#      'TN': 46657101,
#      'n_pred': 3427,
#      'n_ref': 3902}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0263.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0263.nrrd',
#    'metrics': {1: {'Dice': 0.5304777594728172,
#      'IoU': 0.3609865470852018,
#      'FP': 100,
#      'TP': 483,
#      'FN': 755,
#      'TN': 45611718,
#      'n_pred': 583,
#      'n_ref': 1238}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0270.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0270.nrrd',
#    'metrics': {1: {'Dice': 0.7540465850769839,
#      'IoU': 0.6051964512040557,
#      'FP': 274,
#      'TP': 955,
#      'FN': 349,
#      'TN': 41744854,
#      'n_pred': 1229,
#      'n_ref': 1304}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0277.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0277.nrrd',
#    'metrics': {1: {'Dice': 0.42768595041322316,
#      'IoU': 0.2720105124835742,
#      'FP': 505,
#      'TP': 207,
#      'FN': 49,
#      'TN': 51379463,
#      'n_pred': 712,
#      'n_ref': 256}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0278.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0278.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 157,
#      'TP': 0,
#      'FN': 361,
#      'TN': 46136826,
#      'n_pred': 157,
#      'n_ref': 361}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0288.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0288.nrrd',
#    'metrics': {1: {'Dice': 0.4415471534115602,
#      'IoU': 0.2833240379252649,
#      'FP': 2006,
#      'TP': 1016,
#      'FN': 564,
#      'TN': 41742846,
#      'n_pred': 3022,
#      'n_ref': 1580}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0290.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0290.nrrd',
#    'metrics': {1: {'Dice': 0.665074176514961,
#      'IoU': 0.498210585797702,
#      'FP': 1617,
#      'TP': 2645,
#      'FN': 1047,
#      'TN': 44952387,
#      'n_pred': 4262,
#      'n_ref': 3692}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0294.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0294.nrrd',
#    'metrics': {1: {'Dice': 0.6504347826086957,
#      'IoU': 0.48195876288659795,
#      'FP': 159,
#      'TP': 187,
#      'FN': 42,
#      'TN': 32112252,
#      'n_pred': 346,
#      'n_ref': 229}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0295.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0295.nrrd',
#    'metrics': {1: {'Dice': 0.8031496062992126,
#      'IoU': 0.6710526315789473,
#      'FP': 163,
#      'TP': 1020,
#      'FN': 337,
#      'TN': 51378704,
#      'n_pred': 1183,
#      'n_ref': 1357}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0296.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0296.nrrd',
#    'metrics': {1: {'Dice': 0.897448724362181,
#      'IoU': 0.8139745916515426,
#      'FP': 55,
#      'TP': 897,
#      'FN': 150,
#      'TN': 46136242,
#      'n_pred': 952,
#      'n_ref': 1047}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0300.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0300.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 571,
#      'TP': 0,
#      'FN': 1569,
#      'TN': 46135204,
#      'n_pred': 571,
#      'n_ref': 1569}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0305.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0305.nrrd',
#    'metrics': {1: {'Dice': 0.5899379738111648,
#      'IoU': 0.41837732160312807,
#      'FP': 273,
#      'TP': 428,
#      'FN': 322,
#      'TN': 46136321,
#      'n_pred': 701,
#      'n_ref': 750}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0309.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0309.nrrd',
#    'metrics': {1: {'Dice': 0.7552222817354044,
#      'IoU': 0.6067125645438899,
#      'FP': 242,
#      'TP': 705,
#      'FN': 215,
#      'TN': 50330486,
#      'n_pred': 947,
#      'n_ref': 920}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0311.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0311.nrrd',
# ...
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0828.nrrd',
#    'metrics': {1: {'Dice': 0.3658787255909558,
#      'IoU': 0.2238993710691824,
#      'FP': 2687,
#      'TP': 890,
#      'FN': 398,
#      'TN': 53473401,
#      'n_pred': 3577,
#      'n_ref': 1288}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0833.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0833.nrrd',
#    'metrics': {1: {'Dice': 0.711778815806085,
#      'IoU': 0.5525284202273618,
#      'FP': 1866,
#      'TP': 2819,
#      'FN': 417,
#      'TN': 44559378,
#      'n_pred': 4685,
#      'n_ref': 3236}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0836.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0836.nrrd',
#    'metrics': {1: {'Dice': 0.5398611892703058,
#      'IoU': 0.3697327852004111,
#      'FP': 2103,
#      'TP': 1439,
#      'FN': 350,
#      'TN': 37220556,
#      'n_pred': 3542,
#      'n_ref': 1789}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0837.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0837.nrrd',
#    'metrics': {1: {'Dice': 0.40034144259496374,
#      'IoU': 0.2502668089647812,
#      'FP': 1358,
#      'TP': 469,
#      'FN': 47,
#      'TN': 52426926,
#      'n_pred': 1827,
#      'n_ref': 516}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0842.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0842.nrrd',
#    'metrics': {1: {'Dice': 0.5579514824797843,
#      'IoU': 0.38691588785046727,
#      'FP': 695,
#      'TP': 1242,
#      'FN': 1273,
#      'TN': 51901302,
#      'n_pred': 1937,
#      'n_ref': 2515}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0844.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0844.nrrd',
#    'metrics': {1: {'Dice': 0.6226890756302521,
#      'IoU': 0.4521049420378279,
#      'FP': 547,
#      'TP': 741,
#      'FN': 351,
#      'TN': 41744793,
#      'n_pred': 1288,
#      'n_ref': 1092}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0846.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0846.nrrd',
#    'metrics': {1: {'Dice': 0.6504468718967229,
#      'IoU': 0.481972038263429,
#      'FP': 368,
#      'TP': 655,
#      'FN': 336,
#      'TN': 46135985,
#      'n_pred': 1023,
#      'n_ref': 991}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0849.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0849.nrrd',
#    'metrics': {1: {'Dice': 0.6786312514955731,
#      'IoU': 0.5135820354943861,
#      'FP': 741,
#      'TP': 1418,
#      'FN': 602,
#      'TN': 32109879,
#      'n_pred': 2159,
#      'n_ref': 2020}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0855.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0855.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 1713,
#      'TP': 0,
#      'FN': 80,
#      'TN': 44038399,
#      'n_pred': 1713,
#      'n_ref': 80}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0856.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0856.nrrd',
#    'metrics': {1: {'Dice': 0.611740473738414,
#      'IoU': 0.4406528189910979,
#      'FP': 304,
#      'TP': 297,
#      'FN': 73,
#      'TN': 46136670,
#      'n_pred': 601,
#      'n_ref': 370}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0858.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0858.nrrd',
#    'metrics': {1: {'Dice': 0.4470300061236987,
#      'IoU': 0.28785488958990535,
#      'FP': 42,
#      'TP': 365,
#      'FN': 861,
#      'TN': 41941772,
#      'n_pred': 407,
#      'n_ref': 1226}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0872.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0872.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 0,
#      'TP': 0,
#      'FN': 415,
#      'TN': 51379809,
#      'n_pred': 0,
#      'n_ref': 415}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0881.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0881.nrrd',
#    'metrics': {1: {'Dice': 0.6228335625859698,
#      'IoU': 0.4522572912504994,
#      'FP': 332,
#      'TP': 1132,
#      'FN': 1039,
#      'TN': 24081977,
#      'n_pred': 1464,
#      'n_ref': 2171}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0889.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0889.nrrd',
#    'metrics': {1: {'Dice': 0.0,
#      'IoU': 0.0,
#      'FP': 725,
#      'TP': 0,
#      'FN': 44,
#      'TN': 40893695,
#      'n_pred': 725,
#      'n_ref': 44}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0890.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0890.nrrd',
#    'metrics': {1: {'Dice': 0.6880804953560371,
#      'IoU': 0.5244837758112094,
#      'FP': 776,
#      'TP': 889,
#      'FN': 30,
#      'TN': 28899681,
#      'n_pred': 1665,
#      'n_ref': 919}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0892.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0892.nrrd',
#    'metrics': {1: {'Dice': 0.5847243297926151,
#      'IoU': 0.4131522516082916,
#      'FP': 320,
#      'TP': 578,
#      'FN': 501,
#      'TN': 37747337,
#      'n_pred': 898,
#      'n_ref': 1079}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0893.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0893.nrrd',
#    'metrics': {1: {'Dice': 0.47516198704103674,
#      'IoU': 0.311614730878187,
#      'FP': 367,
#      'TP': 220,
#      'FN': 119,
#      'TN': 32111934,
#      'n_pred': 587,
#      'n_ref': 339}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0894.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0894.nrrd',
#    'metrics': {1: {'Dice': 0.8634615384615385,
#      'IoU': 0.7597292724196277,
#      'FP': 66,
#      'TP': 898,
#      'FN': 218,
#      'TN': 41941858,
#      'n_pred': 964,
#      'n_ref': 1116}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0897.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0897.nrrd',
#    'metrics': {1: {'Dice': 0.6666666666666666,
#      'IoU': 0.5,
#      'FP': 141,
#      'TP': 219,
#      'FN': 78,
#      'TN': 45612618,
#      'n_pred': 360,
#      'n_ref': 297}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0902.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0902.nrrd',
#    'metrics': {1: {'Dice': 0.40681733975546497,
#      'IoU': 0.25534883720930235,
#      'FP': 208,
#      'TP': 549,
#      'FN': 1393,
#      'TN': 45086618,
#      'n_pred': 757,
#      'n_ref': 1942}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0912.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0912.nrrd',
#    'metrics': {1: {'Dice': 0.7956989247311828,
#      'IoU': 0.6607142857142857,
#      'FP': 260,
#      'TP': 962,
#      'FN': 234,
#      'TN': 46135888,
#      'n_pred': 1222,
#      'n_ref': 1196}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0913.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0913.nrrd',
#    'metrics': {1: {'Dice': 0.7525539160045402,
#      'IoU': 0.6032757051865332,
#      'FP': 182,
#      'TP': 663,
#      'FN': 254,
#      'TN': 37223349,
#      'n_pred': 845,
#      'n_ref': 917}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0916.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0916.nrrd',
#    'metrics': {1: {'Dice': 0.7435741259593129,
#      'IoU': 0.5918169478378903,
#      'FP': 520,
#      'TP': 3052,
#      'FN': 1585,
#      'TN': 41413595,
#      'n_pred': 3572,
#      'n_ref': 4637}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0919.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0919.nrrd',
#    'metrics': {1: {'Dice': 0.6417797888386124,
#      'IoU': 0.4725152692948362,
#      'FP': 157,
#      'TP': 851,
#      'FN': 793,
#      'TN': 50329847,
#      'n_pred': 1008,
#      'n_ref': 1644}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0920.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0920.nrrd',
#    'metrics': {1: {'Dice': 0.6841940532081378,
#      'IoU': 0.5199809705042816,
#      'FP': 966,
#      'TP': 1093,
#      'FN': 43,
#      'TN': 32110538,
#      'n_pred': 2059,
#      'n_ref': 1136}}},
#   {'reference_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_raw/Dataset117_smal_tumors_MRI_lighter_next_stage/labelsTr/0922.nrrd',
#    'prediction_file': '/media/immersive/KINGSTON/nnUnetData-and-Models/dataset/nnUNet_trained_models/Dataset117_smal_tumors_MRI_lighter_next_stage/nnUNetTrainer_probabilisticOversampling_LastLayerMask__nnUNetPlans__3d_lowres/fold_all/validation/0922.nrrd',
#    'metrics': {1: {'Dice': 0.7431832593532023,
#      'IoU': 0.591321897073663,
#      'FP': 264,
#      'TP': 586,
#      'FN': 141,
#      'TN': 45612065,
#      'n_pred': 850,
#      'n_ref': 727}}}],
#  'mean': {1: {'Dice': 0.5576601936834403,
#    'IoU': 0.42732336468053767,
#    'FP': 694.9352226720648,
#    'TP': 906.1133603238867,
#    'FN': 576.0080971659919,
#    'TN': 41019578.020242915,
#    'n_pred': 1601.0485829959514,
#    'n_ref': 1482.1214574898786}},
#  'foreground_mean': {'Dice': 0.5576601936834403,
#   'IoU': 0.42732336468053767,
#   'FP': 694.9352226720648,
#   'TP': 906.1133603238867,
#   'FN': 576.0080971659919,
#   'TN': 41019578.020242915,
#   'n_pred': 1601.0485829959514,
#   'n_ref': 1482.1214574898786}}
